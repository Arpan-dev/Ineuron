# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
for i in range(0,6):
    for j in range (0,i):
        print("*", end='')
    print()

for i in range(-4,0):
    for j in range(i,0):
        print("*", end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
s=input("Enter a word")
print(s[::-1])
# Out:
# Enter a wordineuron
# norueni
