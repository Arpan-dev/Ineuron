# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
class triangle:
    def __init__(self,a,b,c):
        self.a=a            
        self.b=b
        self.c=c
    
a=float(input("Enter 1st side: "))  
b=float(input("Enter 2nd side: ")) 
c=float(input("Enter 3rd side: "))
    
class triangle_area(triangle):
    def area(self):
        
        s=(self.a+self.b+self.c)/2
        return (s*(s-self.a)*(s-self.b)*(s-self.c))**0.5
    
obj=triangle_area(a,b,c)
print("Area : {}".format(obj.area()))
# Out:
# Enter 1st side: 12.5
# Enter 2nd side: 13.5
# Enter 3rd side: 10
# Area : 59.6992462263972

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def filter_long_word(string,number):
    listwords = []
    for i in string:
        if len(i) > number:
            listwords.append(i)
    return listwords

# %%
l=["rak","arpan das","sohiniii"]

# %%
n=3

# %%
filterlongword(l,n)
# Out:
# ['arpan das', 'sohiniii']

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def func(string):
    return list(map(len,string))

word_list=list(input("Enter the words with comma: ").split(","))
string=[i.strip() for i in word_list]
words_lengths=func(string)
print("Length of the words are: ",words_lengths)
# Out:
# Enter the words with comma: ab,dsd,sdsdwew,eww3xdc
# Length of the words are:  [2, 3, 7, 7]

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def is_vowel(char):
    return char.lower() in 'aeiou'

c=input("Enter the character: ")
is_vowel(c)
# Out:
# Enter the character: a
# True
